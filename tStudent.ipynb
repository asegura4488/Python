# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# %%
df = 2.74

mean, var, skew, kurt = t.stats(df, moments='mvsk')

# %%
print(mean,var,skew)
# Out:
# (array(0.), array(3.7027027), array(nan))

# %%
x = np.linspace(t.ppf(0.01,df),t.ppf(0.99,df),100)

# %%
fig, ax = plt.subplots(1,1)
ax.plot(x,t.pdf(x,df),'r-',lw=5, alpha=0.6, label='t-Student')
ax.legend()

# %%
# generate random numbers

r = t.rvs(df,size=10000)
print(r)
# Out:
# [ -0.26992807  -0.19508199 -16.69452146 ...  -1.77238602  -1.55721884
#    0.69905286]

# %%
fig2, ax = plt.subplots(1,1)
ax.plot(x,t.pdf(x,df),'r-',lw=5, alpha=0.6, label='t-Student')
ax.hist(r,density=True, histtype='stepfilled', alpha=0.5,bins=100)
ax.legend(loc='best',frameon=False)
ax.set_xlim(-10,10)
plt.show()
