# %%
import unicodedata
import string
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("DataBases/covid19_Bogota_Reducido.csv", \
                 sep=";", encoding='latin-1') #index_col='CASO')
df.head(1000)
#df.tail(10)
#df.describe()
# Out:
#         CASO FECHA_DE_INICIO_DE_SINTOMAS FECHA_DIAGNOSTICO    CIUDAD  \
# 0    577.680                         NaN        19/01/2021  Sin dato
# 1    577.681                         NaN        19/01/2021    Bogota
# 2    577.682                  15/01/2021        20/01/2021    Bogota
# 3    577.683                  10/01/2021        21/01/2021    Bogota
# 4    577.684                  11/01/2021        20/01/2021    Bogota
# 5    577.685                  12/01/2021        19/01/2021    Bogota
# 6    577.686                         NaN        20/01/2021  Sin dato
# 7    577.687                         NaN        21/01/2021  Sin dato
# 8    577.688                  15/01/2021        19/01/2021    Bogota
# 9    577.689                  17/01/2021        19/01/2021    Bogota
# 10   577.690                         NaN        20/01/2021  Sin dato
# 11   577.691                         NaN        19/01/2021  Sin dato
# 12   577.692                   7/01/2021        19/01/2021    Bogota
# ...

# %%
# quitar los NaN
#df1 = df.dropna()
df1 = df.fillna('0')
# Advanced
df1 = df.fillna({'FECHA_DE_INICIO_DE_SINTOMAS':-1, 'UBICACION':0})

df1.head(10)
# Out:
#       CASO FECHA_DE_INICIO_DE_SINTOMAS FECHA_DIAGNOSTICO    CIUDAD  \
# 0  577.680                          -1        19/01/2021  Sin dato
# 1  577.681                          -1        19/01/2021    Bogota
# 2  577.682                  15/01/2021        20/01/2021    Bogota
# 3  577.683                  10/01/2021        21/01/2021    Bogota
# 4  577.684                  11/01/2021        20/01/2021    Bogota
# 5  577.685                  12/01/2021        19/01/2021    Bogota
# 6  577.686                          -1        20/01/2021  Sin dato
# 7  577.687                          -1        21/01/2021  Sin dato
# 8  577.688                  15/01/2021        19/01/2021    Bogota
# 9  577.689                  17/01/2021        19/01/2021    Bogota
#
#   LOCALIDAD_ASIS  EDAD  UNI_MED SEXO FUENTE_O_TIPO_DE_CONTAGIO UBICACION  \
# 0       Sin dato    48        1    M                En estudio      Casa
# 1    Teusaquillo    49        1    F                En estudio      Casa
# ...

# %%
#df['CIUDAD']
#df[['CIUDAD','LOCALIDAD_ASIS']]

#Filtrado por localidad
df[df['LOCALIDAD_ASIS'] == 'Ciudad Bolivar']
# Out:
#          CASO FECHA_DE_INICIO_DE_SINTOMAS FECHA_DIAGNOSTICO  CIUDAD  \
# 58    577.738                         NaN        21/01/2021  Bogota
# 67    577.747                   8/01/2021        20/01/2021  Bogota
# 69    577.749                  17/01/2021        19/01/2021  Bogota
# 79    577.759                         NaN        20/01/2021  Bogota
# 109   577.789                         NaN        20/01/2021  Bogota
# 208   577.888                         NaN        20/01/2021  Bogota
# 210   577.890                         NaN        21/01/2021  Bogota
# 222   577.902                         NaN        20/01/2021  Bogota
# 266   577.946                         NaN        20/01/2021  Bogota
# 287   577.967                         NaN        20/01/2021  Bogota
# 291   577.971                  12/01/2021        20/01/2021  Bogota
# 293   577.973                         NaN        20/01/2021  Bogota
# 302   577.982                         NaN        20/01/2021  Bogota
# ...
